# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.
#
# #### Observable Trends based on the data
# 1. The incidence humidity in excess of 100% is extremely rare, based on my sample
# 2. In both the Northern and Southern hemisphere the max. temperature increases as you move towards the equator and decreases as you mover away from the equator. This is born out by significant correlations figures.
# 3. Wind speed seems to be generally lower i.e. under 10 mph in the northern hemisphere between 30 and 40 degrees latitude.
# 4. The highest humidity levels appear to be in the northern hemisphere between 40 and 55 degress latitude.
# 5. There appears to be no correlation between wind speed and latitude in either hemisphere.

# %% [markdown]
# ## Generate Cities List

# %%
# Dependencies
import os
import csv
import requests
import pandas as pd
import json
import matplotlib.pyplot as plt
from config import weather_api_key
from pprint import pprint

import scipy.stats as st
from scipy.stats import linregress
import numpy as np
#from scipy.stats import sem

# %%
# Set up limits to retrieve sample of cities from World Cities csv, by Latitude grouping
# Will be using World Cities listing from https://simplemaps.com/data/world-cities
# and my allocation of latitude groupings to spread the cities across the latitudes.

Latitude_Group_Numbers = [1,2,3,4,5,6,7,8]
Latitude_Group_Max_Cities = [68,118,77,78,88,129,71,11]
lat_g1_cnt=0
lat_g2_cnt=0
lat_g3_cnt=0
lat_g4_cnt=0
lat_g5_cnt=0
lat_g6_cnt=0
lat_g7_cnt=0
lat_g8_cnt=0
world_city_cnt=0
cnt=0

world_city_name = []
world_city_recno = []

# Open the CSV
# Set path for file
csvpath = os.path.join("..","Resources","worldcities.csv")
print(csvpath)
with open(csvpath) as csvfile:
    csvreader = csv.reader(csvfile, delimiter=",")
    csv_header = next(csvreader)
    print(f"CSV Header: {csv_header}")
# Out:
# ..\Resources\worldcities.csv
# CSV Header: ['city', 'city_ascii', 'lat', 'lng', 'country', 'iso2', 'iso3', 'admin_name', 'capital', 'population', 'id', 'Comb_Lat_Long', 'RandPick', 'Longitude Group', 'latitude Group']

# %%
# Loop through looking for the Cities for their latitude grouping and store them up to their maximum allowed.
with open(csvpath) as csvfile:
    csvreader = csv.reader(csvfile, delimiter=",")
    csv_header = next(csvreader)
    csvreader = csv.reader(csvfile, delimiter=",")
#    print(f"CSV Header: {csv_header}")   
    cnt=0
    for row in csvreader:
        lat_group = int(row[11])
# pick only random groups with 1
        if int(row[12]) != 1:
            continue
        elif lat_group < 6 and (lat_g1_cnt < Latitude_Group_Max_Cities[0]):
            lat_g1_cnt +=1
            world_city_name.append(row[1])
            world_city_recno.append(f"{lat_g1_cnt} of Set 1")
        elif lat_group == 6 and (lat_g2_cnt < Latitude_Group_Max_Cities[1]):
            lat_g2_cnt +=1
            world_city_name.append(row[1])
            world_city_recno.append(f"{lat_g2_cnt} of Set 2")
        elif lat_group < 11 and (lat_g3_cnt < Latitude_Group_Max_Cities[2]):
            lat_g3_cnt +=1
            world_city_name.append(row[1])
            world_city_recno.append(f"{lat_g3_cnt} of Set 3")
        elif lat_group == 12 and (lat_g4_cnt < Latitude_Group_Max_Cities[3]):
            lat_g4_cnt +=1
            world_city_name.append(row[1])
            world_city_recno.append(f"{lat_g4_cnt} of Set 4")
        elif lat_group < 19 and (lat_g5_cnt < Latitude_Group_Max_Cities[4]):
            lat_g5_cnt = lat_g5_cnt + 1
            world_city_name.append(row[1])
            world_city_recno.append(f"{lat_g5_cnt} of Set 5")
        elif lat_group < 26 and (lat_g6_cnt < Latitude_Group_Max_Cities[5]):
            lat_g6_cnt +=1
            world_city_name.append(row[1])
            world_city_recno.append(f"{lat_g6_cnt} of Set 6")
        elif lat_group < 41 and (lat_g7_cnt < Latitude_Group_Max_Cities[6]):
            lat_g7_cnt +=1
            world_city_name.append(row[1])
            world_city_recno.append(f"{lat_g7_cnt} of Set 7")            
        elif lat_group < 65 and (lat_g8_cnt < Latitude_Group_Max_Cities[7]):
            lat_g8_cnt +=1
            world_city_name.append(row[1])
            world_city_recno.append(f"{lat_g8_cnt} of Set 8")   

print("Counts of Cities to be used by Latitude group: ",lat_g1_cnt," ",lat_g2_cnt," ",lat_g3_cnt," ",lat_g4_cnt," ",lat_g5_cnt," ",lat_g6_cnt," ",lat_g7_cnt," ",lat_g8_cnt)
# Out:
# Counts of Cities to be used by Latitude group:  68   118   77   59   88   129   71   11

# %%
#print(world_city_id[0])
print(len(world_city_name))
print(world_city_name[2])
print(world_city_recno[2])
# Out:
# 621
# Sasovo
# 1 of Set 5

# %%
# Set up lists to store retrieved data from Open Weather
City_ID=[]
City=[]
Cloudiness=[]
Country=[]
Date=[]
Humidity=[]
Lat=[]
Lng=[]
MaxTemp=[]
WindSpeed=[]

# %%
world_city_recno[1]
world_city_record_df = pd.DataFrame(world_city_name).join(pd.DataFrame(world_city_recno),lsuffix="left",rsuffix="right")
world_city_record_df

world_city_record_sorted_df = world_city_record_df.sort_values('0right')
world_city_record_sorted_df
# Out:
#            0left       0right
# 1    Montecristi   1 of Set 1
# 4     Birkenfeld   1 of Set 2
# 0      Valenzano   1 of Set 3
# 17        Sedico   1 of Set 4
# 2         Sasovo   1 of Set 5
# ..           ...          ...
# 506   Santa Cruz  97 of Set 6
# 481      Avallon  98 of Set 2
# 508      Wyoming  98 of Set 6
# 483        Engen  99 of Set 2
# 512       Shoyna  99 of Set 6
#
# [621 rows x 2 columns]

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Setup the base query with the variable parameters - to use the By City ID Api
#  api.openweathermap.org/data/2.5/weather?id={city id}&appid={API key}
# query_url = (f"http://api.openweathermap.org/data/2.5/weather?id={world_city_id[i]}&appid={weather_api_key}&units={units}")

# Set units to Farenheit and miles per hour.
units = "imperial"  
city_cnt=0
for i in range(len(world_city_name)):
    query_url = (f"http://api.openweathermap.org/data/2.5/weather?q={world_city_name[i]}&appid={weather_api_key}&units={units}")
    city_response = requests.get(query_url).json()
    try:
        City_ID.append(city_response["id"])
        City.append(city_response["name"])
        Cloudiness.append(city_response["clouds"]["all"])
        Country.append(city_response["sys"]["country"])
        Date.append(city_response["dt"])
        Humidity.append(city_response["main"]["humidity"])
        Lat.append(city_response["coord"]["lat"])
        Lng.append(city_response["coord"]["lon"])
        MaxTemp.append(city_response["main"]["temp_max"])
        WindSpeed.append(city_response['wind']['speed'])
        city_cnt +=1
        print(f"Processing Record {world_city_recno[i]} | {world_city_name[i]}")
    except KeyError:
        print(f"City not found: {world_city_name[i]}")

print(f"Number of cities retrieved: {len(City)} ")

#pprint(city_response["id"])
#pprint(city_response["name"])
#pprint(city_response["clouds"]["all"])
#pprint(city_response["sys"]["country"])
#pprint(city_response["dt"])
#pprint(city_response["main"]["humidity"])
#pprint(city_response["coord"]["lat"])
#pprint(city_response["coord"]["lon"])
#pprint(city_response["main"]["temp_max"])
#print(f"{city_response['wind']['speed']} mph")
# Out:
# Processing Record 1 of Set 3 | Valenzano
# Processing Record 1 of Set 1 | Montecristi
# Processing Record 1 of Set 5 | Sasovo
# Processing Record 2 of Set 5 | Pante Macassar
# Processing Record 1 of Set 2 | Birkenfeld
# Processing Record 1 of Set 7 | Saint-Calixte
# Processing Record 2 of Set 3 | Mionica
# Processing Record 3 of Set 3 | Seravezza
# Processing Record 2 of Set 7 | New Prague
# Processing Record 3 of Set 7 | Chuncheon
# City not found: Hoxut
# Processing Record 2 of Set 2 | Halstead
# Processing Record 2 of Set 6 | Bryan
# Processing Record 3 of Set 5 | Balabagan
# City not found: Cape Breton
# Processing Record 4 of Set 7 | Adamstown
# City not found: Talaigua Nuevo
# Processing Record 1 of Set 4 | Sedico
# Processing Record 3 of Set 2 | Petrolina
# Processing Record 4 of Set 6 | Bridge City
# Processing Record 5 of Set 6 | Qianxi
# Processing Record 5 of Set 7 | Iowa Falls
# Processing Record 4 of Set 2 | Amersham
# Processing Record 5 of Set 3 | Simunul
# Processing Record 6 of Set 6 | Pichidegua
# Processing Record 7 of Set 6 | Simsbury Center
# Processing Record 4 of Set 5 | Tiwi
# Processing Record 5 of Set 2 | Montmorillon
# Processing Record 5 of Set 5 | Guanajuato
# Processing Record 2 of Set 1 | Saint-Peray
# Processing Record 6 of Set 3 | Paceco
# Processing Record 8 of Set 6 | San Buenaventura
# Processing Record 6 of Set 5 | Candelaria
# Processing Record 7 of Set 3 | Peshkopi
# Processing Record 9 of Set 6 | Pickering
# Processing Record 10 of Set 6 | Wenxian Chengguanzhen
# Processing Record 7 of Set 5 | Giporlos
# Processing Record 2 of Set 4 | Krosno Odrzanskie
# Processing Record 6 of Set 2 | Cran-Gevrier
# Processing Record 11 of Set 6 | Oak Grove
# Processing Record 3 of Set 1 | Bundibugyo
# Processing Record 6 of Set 7 | Huaishu
# Processing Record 12 of Set 6 | Strunino
# Processing Record 3 of Set 4 | Miren
# City not found: Catape
# City not found: 'Ain Roua
# Processing Record 7 of Set 7 | Aqsu
# Processing Record 8 of Set 3 | Bucine
# Processing Record 8 of Set 5 | Tabriz
# City not found: Douar Souk L`qolla
# Processing Record 9 of Set 5 | Bukan
# City not found: Muquem de Sao Francisco
# Processing Record 7 of Set 1 | Corbera de Llobregat
# Processing Record 10 of Set 5 | Valka
# Processing Record 13 of Set 6 | Lieksa
# Processing Record 8 of Set 1 | Bandundu
# Processing Record 9 of Set 1 | Touba
# Processing Record 8 of Set 2 | Auxonne
# Processing Record 9 of Set 2 | Viroflay
# Processing Record 9 of Set 3 | Sogne
# Processing Record 10 of Set 2 | Saint-Mande
# Processing Record 11 of Set 5 | Salinas
# Processing Record 10 of Set 1 | Vicosa do Ceara
# Processing Record 11 of Set 1 | Chichaoua
# Processing Record 8 of Set 7 | Westlake Village
# Processing Record 12 of Set 1 | Natitingou
# Processing Record 9 of Set 7 | Mandurah
# Processing Record 4 of Set 4 | Komadi
# Processing Record 12 of Set 5 | Pijijiapan
# Processing Record 1 of Set 8 | Okhotsk
# Processing Record 11 of Set 2 | Mitry-Mory
# Processing Record 10 of Set 3 | Kalymnos
# Processing Record 14 of Set 6 | Murmansk
# Processing Record 12 of Set 2 | Barnstaple
# Processing Record 11 of Set 3 | Boavita
# Processing Record 15 of Set 6 | East Rockaway
# Processing Record 13 of Set 5 | Ponduru
# Processing Record 13 of Set 1 | Lancon-Provence
# Processing Record 14 of Set 1 | Villafranca de los Barros
# Processing Record 16 of Set 6 | Withamsville
# Processing Record 13 of Set 2 | Great Wakering
# Processing Record 14 of Set 2 | Gravata
# Processing Record 5 of Set 4 | Nyiradony
# Processing Record 10 of Set 7 | Hurricane
# Processing Record 15 of Set 1 | Victoria
# Processing Record 14 of Set 5 | Santa Maria
# Processing Record 17 of Set 6 | Franklin Center
# Processing Record 15 of Set 5 | Novoanninskiy
# Processing Record 18 of Set 6 | Maryland City
# Processing Record 15 of Set 2 | Casinhas
# Processing Record 16 of Set 5 | Sao Pedro do Sul
# Processing Record 11 of Set 7 | Rosamond
# Processing Record 19 of Set 6 | Pendleton
# Processing Record 20 of Set 6 | Hopkinton
# Processing Record 16 of Set 2 | Ripponden
# Processing Record 21 of Set 6 | Salem
# Processing Record 12 of Set 3 | Bredasdorp
# Processing Record 17 of Set 5 | Chajul
# Processing Record 16 of Set 1 | Nava
# Processing Record 17 of Set 2 | Vannes
# Processing Record 22 of Set 6 | Francisco I. Madero
# Processing Record 18 of Set 2 | Purmerend
# Processing Record 23 of Set 6 | Hapur
# Processing Record 24 of Set 6 | Clinton
# Processing Record 18 of Set 5 | Ban Duea
# City not found: Ban Chorakhe Samphan
# Processing Record 25 of Set 6 | Wyndmoor
# Processing Record 7 of Set 4 | Pasching
# Processing Record 12 of Set 7 | Rockwood
# Processing Record 26 of Set 6 | Dunn
# Processing Record 19 of Set 2 | Leutenbach
# Processing Record 27 of Set 6 | Mardan
# Processing Record 20 of Set 2 | Raismes
# Processing Record 21 of Set 2 | Hellenthal
# Processing Record 13 of Set 3 | Santo Antonio da Alegria
# Processing Record 13 of Set 7 | Saguenay
# Processing Record 17 of Set 1 | Gorom-Gorom
# Processing Record 14 of Set 7 | Laixi
# Processing Record 19 of Set 5 | Santana da Boa Vista
# Processing Record 22 of Set 2 | Mchinji
# Processing Record 15 of Set 7 | Linquan
# Processing Record 23 of Set 2 | Joaquim Gomes
# Processing Record 28 of Set 6 | Reserve
# Processing Record 24 of Set 2 | Le Coteau
# Processing Record 8 of Set 4 | Gubin
# Processing Record 14 of Set 3 | Molinella
# Processing Record 29 of Set 6 | Brookfield
# Processing Record 18 of Set 1 | Kiruhura
# Processing Record 15 of Set 3 | Itapebi
# Processing Record 25 of Set 2 | Loftus
# Processing Record 16 of Set 7 | Nagasu
# Processing Record 30 of Set 6 | Fairview
# Processing Record 16 of Set 3 | Eldorado
# City not found: Balboa Heights
# Processing Record 31 of Set 6 | New Providence
# Processing Record 17 of Set 7 | Dongcun
# Processing Record 32 of Set 6 | Haddam
# Processing Record 26 of Set 2 | Bad Essen
# Processing Record 18 of Set 7 | Rosemont
# Processing Record 20 of Set 5 | Myronivka
# Processing Record 21 of Set 5 | Primorsko-Akhtarsk
# Processing Record 18 of Set 3 | Barrancabermeja
# Processing Record 27 of Set 2 | Tralee
# Processing Record 19 of Set 1 | Valga
# Processing Record 28 of Set 2 | Wiehl
# City not found: Alexania
# Processing Record 20 of Set 1 | Rianxo
# City not found: Campo Alegre de Lourdes
# Processing Record 22 of Set 5 | Villa de Alvarez
# Processing Record 19 of Set 7 | Rosemere
# City not found: Kvivik
# Processing Record 30 of Set 2 | Altbach
# Processing Record 23 of Set 5 | Chervonohryhorivka
# City not found: Cadereyta Jimenez
# Processing Record 21 of Set 1 | La Spezia
# Processing Record 20 of Set 7 | Labytnangi
# Processing Record 9 of Set 4 | Vorchdorf
# Processing Record 34 of Set 6 | Hutto
# Processing Record 35 of Set 6 | Boston
# Processing Record 36 of Set 6 | Oxford
# Processing Record 21 of Set 3 | Polykastro
# Processing Record 24 of Set 5 | Meycauayan
# Processing Record 10 of Set 4 | Sturovo
# Processing Record 31 of Set 2 | Canapolis
# Processing Record 32 of Set 2 | Blainville-sur-Orne
# Processing Record 22 of Set 3 | Livorno
# Processing Record 33 of Set 2 | Nogent-sur-Marne
# Processing Record 23 of Set 3 | Cuparaque
# Processing Record 37 of Set 6 | New City
# Processing Record 25 of Set 5 | Belen
# Processing Record 11 of Set 4 | Purkersdorf
# Processing Record 21 of Set 7 | Revda
# Processing Record 26 of Set 5 | Osmanabad
# Processing Record 34 of Set 2 | Mata Grande
# Processing Record 22 of Set 1 | Benguela
# Processing Record 23 of Set 1 | Choro
# Processing Record 27 of Set 5 | Mus
# Processing Record 2 of Set 8 | Prairie Ridge
# Processing Record 24 of Set 3 | Urucania
# Processing Record 24 of Set 1 | Huaquillas
# Processing Record 35 of Set 2 | Heywood
# Processing Record 36 of Set 2 | Concorezzo
# Processing Record 25 of Set 3 | Yupiltepeque
# Processing Record 37 of Set 2 | Ecublens
# Processing Record 38 of Set 6 | Qingyang
# Processing Record 22 of Set 7 | Hatsukaichi
# Processing Record 26 of Set 3 | Tire
# Processing Record 28 of Set 5 | Vinsady
# Processing Record 38 of Set 2 | Kortessem
# Processing Record 39 of Set 2 | Buique
# Processing Record 12 of Set 4 | Slovenj Gradec
# City not found: Smithfield Heights
# Processing Record 40 of Set 2 | Barra da Estiva
# Processing Record 27 of Set 3 | Rio de Janeiro
# Processing Record 41 of Set 2 | Yate
# Processing Record 42 of Set 2 | Esch-sur-Alzette
# Processing Record 23 of Set 7 | Cessnock
# Processing Record 24 of Set 7 | Saranpaul
# Processing Record 25 of Set 7 | Hiroshima
# Processing Record 40 of Set 6 | Gowanda
# Processing Record 29 of Set 5 | Halisahar
# Processing Record 13 of Set 4 | Hajduboszormeny
# Processing Record 26 of Set 7 | Susanville
# Processing Record 43 of Set 2 | Warminster
# City not found: Al Orjane
# Processing Record 44 of Set 2 | Darlington
# Processing Record 45 of Set 2 | Onnaing
# Processing Record 30 of Set 5 | Embalse
# Processing Record 28 of Set 3 | Calatafimi
# Processing Record 29 of Set 3 | Rignano Flaminio
# Processing Record 30 of Set 3 | Chimbote
# Processing Record 46 of Set 2 | Darmstadt
# Processing Record 41 of Set 6 | Seymour
# Processing Record 14 of Set 4 | Hengersberg
# Processing Record 47 of Set 2 | Plympton
# Processing Record 48 of Set 2 | Lubbeek
# City not found: Zhongbai
# Processing Record 43 of Set 6 | Paris
# Processing Record 49 of Set 2 | Joao Pessoa
# Processing Record 15 of Set 4 | Grossbreitenbach
# Processing Record 44 of Set 6 | Georgetown
# Processing Record 50 of Set 2 | IJmuiden
# Processing Record 31 of Set 5 | Talsi
# Processing Record 45 of Set 6 | Darjazin
# Processing Record 26 of Set 1 | Mazan
# Processing Record 46 of Set 6 | Swanzey
# Processing Record 27 of Set 7 | Sue
# City not found: Skenderaj
# Processing Record 28 of Set 7 | Changchun
# Processing Record 32 of Set 5 | Salcedo
# Processing Record 33 of Set 5 | Gurpinar
# Processing Record 27 of Set 1 | Estremoz
# Processing Record 51 of Set 2 | Agrestina
# Processing Record 47 of Set 6 | Melvindale
# Processing Record 32 of Set 3 | Stornarella
# Processing Record 52 of Set 2 | Pledran
# Processing Record 48 of Set 6 | Holyoke
# Processing Record 28 of Set 1 | Guatavita
# Processing Record 53 of Set 2 | Panazol
# Processing Record 49 of Set 6 | Xinmin
# Processing Record 33 of Set 3 | Malo Crnice
# Processing Record 29 of Set 1 | Baiao
# Processing Record 50 of Set 6 | Alamo Heights
# Processing Record 30 of Set 1 | Hithadhoo
# Processing Record 29 of Set 7 | Ivins
# Processing Record 16 of Set 4 | Brunico
# Processing Record 31 of Set 1 | Barreirinha
# Processing Record 51 of Set 6 | Calverton
# Processing Record 52 of Set 6 | Hot Springs
# Processing Record 54 of Set 2 | Flers
# Processing Record 34 of Set 3 | Castelnuovo Berardenga
# Processing Record 55 of Set 2 | Rapperswil-Jona
# Processing Record 32 of Set 1 | Soure
# Processing Record 17 of Set 4 | Trieste
# Processing Record 53 of Set 6 | St. Albans
# Processing Record 35 of Set 3 | Linden
# Processing Record 36 of Set 3 | Tirana
# City not found: Nakashunbetsu
# Processing Record 31 of Set 7 | Burbank
# Processing Record 37 of Set 3 | Calheta
# Processing Record 54 of Set 6 | Ellwood City
# Processing Record 56 of Set 2 | Bolton
# Processing Record 57 of Set 2 | Neustadt
# Processing Record 18 of Set 4 | Debica
# Processing Record 19 of Set 4 | Vrutky
# Processing Record 34 of Set 5 | Khon Kaen
# Processing Record 33 of Set 1 | Torre de Moncorvo
# Processing Record 35 of Set 5 | Gorodishche
# Processing Record 34 of Set 1 | Ipiales
# Processing Record 38 of Set 3 | Natividade da Serra
# Processing Record 55 of Set 6 | Hassan Abdal
# Processing Record 36 of Set 5 | Marivan
# Processing Record 39 of Set 3 | Aci Castello
# Processing Record 32 of Set 7 | Fruit Heights
# City not found: East Zorra-Tavistock
# Processing Record 33 of Set 7 | Woodcrest
# City not found: Bab Boudir
# Processing Record 58 of Set 2 | Brentwood
# Processing Record 20 of Set 4 | Krk
# Processing Record 40 of Set 3 | Struga
# Processing Record 21 of Set 4 | Namestovo
# Processing Record 41 of Set 3 | Ibiraci
# Processing Record 37 of Set 5 | Monte Escobedo
# City not found: Tmassah
# Processing Record 34 of Set 7 | Xingcheng
# City not found: Toksun
# Processing Record 43 of Set 3 | Santana
# Processing Record 38 of Set 5 | Himamaylan
# Processing Record 35 of Set 7 | South Whittier
# Processing Record 36 of Set 1 | Sao Benedito
# Processing Record 58 of Set 6 | Monaca
# Processing Record 59 of Set 2 | Ahaus
# Processing Record 59 of Set 6 | Beloozerskiy
# Processing Record 44 of Set 3 | Capranica
# Processing Record 45 of Set 3 | Piana degli Albanesi
# Processing Record 60 of Set 2 | Corsham
# Processing Record 46 of Set 3 | Reggello
# Processing Record 39 of Set 5 | Amravati
# Processing Record 61 of Set 2 | Roncq
# City not found: Granito
# Processing Record 36 of Set 7 | Zmeinogorsk
# Processing Record 47 of Set 3 | Jiquilisco
# Processing Record 48 of Set 3 | Iaras
# Processing Record 63 of Set 2 | Serris
# City not found: Gia Nghia
# Processing Record 64 of Set 2 | Capriolo
# Processing Record 37 of Set 7 | Kunsan
# City not found: Tabernes de Valldigna
# Processing Record 65 of Set 2 | Iringa
# Processing Record 60 of Set 6 | Country Club Estates
# Processing Record 66 of Set 2 | Harrow on the Hill
# City not found: Tsukuba-kenkyugakuen-toshi
# Processing Record 39 of Set 7 | Daly City
# City not found: Toudouni
# Processing Record 61 of Set 6 | Plainview
# Processing Record 67 of Set 2 | Fenton
# Processing Record 68 of Set 2 | Chateaudun
# Processing Record 49 of Set 3 | Zabbar
# Processing Record 40 of Set 7 | West Point
# Processing Record 69 of Set 2 | Kluang
# Processing Record 70 of Set 2 | Taguatinga
# Processing Record 62 of Set 6 | Angier
# Processing Record 23 of Set 4 | Casarsa della Delizia
# Processing Record 41 of Set 7 | Sanhe
# Processing Record 39 of Set 1 | Gelves
# Processing Record 63 of Set 6 | Dongping
# Processing Record 40 of Set 5 | Kutaisi
# Processing Record 41 of Set 5 | Bijapur
# Processing Record 64 of Set 6 | Ellington
# City not found: St. Martinville
# Processing Record 40 of Set 1 | Tinzart
# Processing Record 50 of Set 3 | Cellino San Marco
# Processing Record 66 of Set 6 | Malahide
# Processing Record 71 of Set 2 | Kidderminster
# Processing Record 72 of Set 2 | Souffelweyersheim
# Processing Record 42 of Set 7 | Lianshan
# Processing Record 51 of Set 3 | Monte Urano
# Processing Record 43 of Set 7 | Vail
# Processing Record 42 of Set 5 | Berriozabal
# Processing Record 24 of Set 4 | Pfaffenhofen an der Roth
# City not found: Zhujiagua
# Processing Record 73 of Set 2 | Moelan-sur-Mer
# Processing Record 52 of Set 3 | Borda da Mata
# Processing Record 67 of Set 6 | Pinewood
# Processing Record 68 of Set 6 | Suffield
# Processing Record 43 of Set 5 | Apatzingan de la Constitucion
# Processing Record 74 of Set 2 | Risca
# City not found: Granichen
# Processing Record 25 of Set 4 | Baurci
# City not found: Liujiaxia
# Processing Record 69 of Set 6 | Garrett
# Processing Record 76 of Set 2 | Kilkenny
# Processing Record 77 of Set 2 | Doorn
# Processing Record 41 of Set 1 | Leguevin
# Processing Record 26 of Set 4 | Siquinala
# Processing Record 46 of Set 7 | Poway
# Processing Record 78 of Set 2 | Japi
# City not found: East Donegal
# Processing Record 44 of Set 5 | Margosatubig
# Processing Record 71 of Set 6 | Munster
# Processing Record 42 of Set 1 | Odemira
# Processing Record 45 of Set 5 | Sambalpur
# Processing Record 72 of Set 6 | Sharya
# Processing Record 73 of Set 6 | Norton
# Processing Record 74 of Set 6 | Bazarak
# Processing Record 75 of Set 6 | Guimba
# Processing Record 46 of Set 5 | Cabaiguan
# Processing Record 27 of Set 4 | Pozo Colorado
# Processing Record 76 of Set 6 | Sambrial
# Processing Record 53 of Set 3 | Giovinazzo
# Processing Record 54 of Set 3 | Sao Jose do Rio Preto
# Processing Record 47 of Set 7 | Blagoveshchensk
# Processing Record 28 of Set 4 | Cerrillos
# Processing Record 79 of Set 2 | Porto da Folha
# Processing Record 77 of Set 6 | Halfway
# Processing Record 55 of Set 3 | Brena Baja
# Processing Record 43 of Set 1 | Upper Buchanan
# Processing Record 80 of Set 2 | Uedem
# Processing Record 29 of Set 4 | Bockenem
# Processing Record 81 of Set 2 | Whitworth
# Processing Record 82 of Set 2 | Wednesfield
# Processing Record 30 of Set 4 | Schellerten
# Processing Record 78 of Set 6 | Sibay
# Processing Record 44 of Set 1 | Nakuru
# Processing Record 47 of Set 5 | Alfonso
# Processing Record 48 of Set 7 | Weichanglu
# Processing Record 56 of Set 3 | Omdurman
# Processing Record 45 of Set 1 | Chabeuil
# City not found: Roda del Ter
# Processing Record 49 of Set 7 | Marysville
# Processing Record 57 of Set 3 | San Ramon
# Processing Record 47 of Set 1 | Campoalegre
# Processing Record 31 of Set 4 | Zittau
# Processing Record 48 of Set 1 | Gignac
# Processing Record 32 of Set 4 | Sencur
# Processing Record 79 of Set 6 | San Vicente
# Processing Record 48 of Set 5 | Tartu
# Processing Record 83 of Set 2 | Chaddesden
# Processing Record 84 of Set 2 | Reinach
# Processing Record 85 of Set 2 | Netphen
# City not found: Xiaozui
# Processing Record 86 of Set 2 | Rethel
# Processing Record 80 of Set 6 | Golden Gate
# Processing Record 51 of Set 7 | Austin
# Processing Record 87 of Set 2 | Duiven
# Processing Record 88 of Set 2 | Untergrombach
# Processing Record 89 of Set 2 | Gennevilliers
# Processing Record 81 of Set 6 | Taylor
# Processing Record 49 of Set 1 | Koutiala
# Processing Record 90 of Set 2 | Thalwil
# Processing Record 82 of Set 6 | Homer Glen
# Processing Record 49 of Set 5 | Lubny
# Processing Record 91 of Set 2 | Chiavenna
# Processing Record 52 of Set 7 | Yosemite Lakes
# Processing Record 83 of Set 6 | Portage
# Processing Record 53 of Set 7 | Fremont
# Processing Record 50 of Set 1 | Valverde de la Virgen
# City not found: Birkenes
# Processing Record 33 of Set 4 | Musile di Piave
# Processing Record 51 of Set 1 | Sotik
# Processing Record 34 of Set 4 | Bender
# Processing Record 84 of Set 6 | Amityville
# Processing Record 54 of Set 7 | Lysterfield
# Processing Record 3 of Set 8 | Coquitlam
# Processing Record 85 of Set 6 | St. Catharines
# Processing Record 92 of Set 2 | Warrington
# City not found: Ban Bang Krang
# Processing Record 52 of Set 1 | Cervello
# Processing Record 59 of Set 3 | Racari
# Processing Record 86 of Set 6 | Marshfield
# Processing Record 36 of Set 4 | Bo Phloi
# Processing Record 60 of Set 3 | Nea Moudania
# City not found: Wawizaght
# Processing Record 55 of Set 7 | Nong'an
# Processing Record 61 of Set 3 | Chivolo
# Processing Record 50 of Set 5 | Kakinada
# Processing Record 37 of Set 4 | Rochedo
# Processing Record 38 of Set 4 | Schwechat
# City not found: Santa Maria Yucuhiti
# Processing Record 39 of Set 4 | Kruhlaye
# Processing Record 87 of Set 6 | Natchez
# City not found: Amatenango de la Frontera
# Processing Record 53 of Set 5 | Matelandia
# Processing Record 54 of Set 1 | Fos-sur-Mer
# Processing Record 62 of Set 3 | Cercola
# Processing Record 63 of Set 3 | Nuevo Cuscatlan
# Processing Record 88 of Set 6 | Hampstead
# Processing Record 55 of Set 1 | Salinas
# Processing Record 93 of Set 2 | Obdam
# Processing Record 56 of Set 7 | Xiaoyi
# Processing Record 54 of Set 5 | Maha Sarakham
# Processing Record 55 of Set 5 | Tupancireta
# Processing Record 94 of Set 2 | Glandorf
# Processing Record 40 of Set 4 | Michalovce
# Processing Record 56 of Set 1 | Serta
# Processing Record 41 of Set 4 | Gorizia
# Processing Record 64 of Set 3 | Corinto
# City not found: Ait Faska
# Processing Record 65 of Set 3 | Metapan
# Processing Record 56 of Set 5 | Boca del Rio
# Processing Record 89 of Set 6 | Swartz Creek
# Processing Record 90 of Set 6 | Muynoq
# Processing Record 66 of Set 3 | Castellaneta
# Processing Record 42 of Set 4 | Sao Pedro do Ivai
# City not found: Oulad Hassoune
# Processing Record 57 of Set 5 | Novolakskoye
# Processing Record 43 of Set 4 | Damanhur
# Processing Record 91 of Set 6 | Pequannock
# Processing Record 59 of Set 1 | Monserrato
# Processing Record 95 of Set 2 | Zundert
# Processing Record 96 of Set 2 | Le Bourget-du-Lac
# Processing Record 44 of Set 4 | Kirchbichl
# Processing Record 60 of Set 1 | Adra
# Processing Record 97 of Set 2 | Ottweiler
# Processing Record 57 of Set 7 | Pyeongtaek
# Processing Record 92 of Set 6 | Lyons
# Processing Record 67 of Set 3 | Scornicesti
# Processing Record 93 of Set 6 | Weddington
# City not found: Sofiyivs'ka Borshchahivka
# City not found: Alcora
# Processing Record 62 of Set 1 | Eseka
# Processing Record 98 of Set 2 | Avallon
# Processing Record 45 of Set 4 | Strakonice
# Processing Record 99 of Set 2 | Engen
# Processing Record 46 of Set 4 | Saveni
# Processing Record 63 of Set 1 | Iwo
# Processing Record 59 of Set 5 | Jiutepec
# Processing Record 58 of Set 7 | Valley City
# Processing Record 59 of Set 7 | Wood River
# Processing Record 64 of Set 1 | Puget-sur-Argens
# Processing Record 4 of Set 8 | Polson
# Processing Record 68 of Set 3 | Krumovgrad
# City not found: Cassongue
# Processing Record 66 of Set 1 | Tobarra
# Processing Record 60 of Set 5 | Viamao
# Processing Record 47 of Set 4 | Wittstock
# Processing Record 48 of Set 4 | Lwowek Slaski
# Processing Record 60 of Set 7 | Rhinelander
# Processing Record 69 of Set 3 | Castiglione della Pescaia
# Processing Record 100 of Set 2 | Kaedi
# Processing Record 61 of Set 5 | Sagaing
# Processing Record 94 of Set 6 | Gaoniang
# Processing Record 95 of Set 6 | Calanasan
# Processing Record 101 of Set 2 | Isselburg
# City not found: Itaipe
# Processing Record 96 of Set 6 | Seaford
# Processing Record 97 of Set 6 | Santa Cruz
# Processing Record 102 of Set 2 | Eppingen
# Processing Record 98 of Set 6 | Wyoming
# Processing Record 67 of Set 1 | Bogo
# Processing Record 103 of Set 2 | Villeneuve-la-Garenne
# City not found: Assais
# City not found: Shoyna
# Processing Record 100 of Set 6 | Luba
# Processing Record 71 of Set 3 | Fonsorbes
# City not found: Varzea Nova
# Processing Record 62 of Set 5 | Rafael Castillo
# Processing Record 61 of Set 7 | Zhengding
# City not found: Sidi Dahbi
# Processing Record 49 of Set 4 | Guzolandia
# Processing Record 63 of Set 5 | Chachahuantla
# Processing Record 101 of Set 6 | Zhanggu
# Processing Record 73 of Set 3 | Chalkida
# Processing Record 102 of Set 6 | Airmont
# City not found: Zhipingxiang
# Processing Record 63 of Set 7 | Hillsborough
# Processing Record 105 of Set 2 | Chevilly-Larue
# Processing Record 50 of Set 4 | Banska Bystrica
# Processing Record 103 of Set 6 | River Edge
# Processing Record 74 of Set 3 | Vaison-la-Romaine
# Processing Record 75 of Set 3 | Taza
# Processing Record 106 of Set 2 | Great Burstead
# Processing Record 64 of Set 7 | Mountain Home
# Processing Record 65 of Set 7 | Barnhart
# Processing Record 107 of Set 2 | Querqueville
# Processing Record 64 of Set 5 | San Martin Hidalgo
# Processing Record 65 of Set 5 | Sampaloc
# Processing Record 66 of Set 5 | San Miguel Panixtlahuaca
# City not found: St. Ann
# Processing Record 104 of Set 6 | Carrboro
# City not found: Francinopolis
# Processing Record 76 of Set 3 | Dozza
# Processing Record 109 of Set 2 | Niedereschach
# Processing Record 67 of Set 5 | Yenotayevka
# City not found: Tabernes Blanques
# Processing Record 68 of Set 5 | Itapeva
# Processing Record 69 of Set 5 | Zarraga
# Processing Record 70 of Set 5 | Brianka
# Processing Record 71 of Set 5 | Nida
# Processing Record 72 of Set 5 | Cardenas
# Processing Record 67 of Set 7 | Azusa
# Processing Record 105 of Set 6 | Kara-Suu
# Processing Record 110 of Set 2 | Sumbawanga
# Processing Record 73 of Set 5 | Bafra
# Processing Record 51 of Set 4 | Glauchau
# Processing Record 74 of Set 5 | Birak
# Processing Record 111 of Set 2 | Trebur
# Processing Record 106 of Set 6 | Waukegan
# City not found: Gracanice
# Processing Record 112 of Set 2 | Norden
# City not found: West St. Paul
# Processing Record 113 of Set 2 | Neuenrade
# Processing Record 114 of Set 2 | Henfield
# Processing Record 107 of Set 6 | Pleasantville
# City not found: Souk Khmis Bni Arouss
# Processing Record 77 of Set 5 | Larvik
# Processing Record 69 of Set 7 | Dashiqiao
# Processing Record 78 of Set 5 | Makiivka
# Processing Record 79 of Set 5 | Bonnybridge
# Processing Record 108 of Set 6 | Flatwoods
# Processing Record 80 of Set 5 | Montevideo
# Processing Record 81 of Set 5 | Massa Marittima
# Processing Record 82 of Set 5 | Buesaco
# Processing Record 70 of Set 7 | Kani
# Processing Record 71 of Set 7 | Air Force Academy
# Processing Record 115 of Set 2 | Hambrucken
# Processing Record 109 of Set 6 | Ciudad Apodaca
# Processing Record 116 of Set 2 | Bourne
# Processing Record 83 of Set 5 | Soller
# Processing Record 110 of Set 6 | Queens
# Processing Record 84 of Set 5 | Villa Mercedes
# Processing Record 85 of Set 5 | Fundao
# Processing Record 117 of Set 2 | Bergamo
# Processing Record 118 of Set 2 | Parana
# Processing Record 86 of Set 5 | Owando
# City not found: Upper Leacock
# Processing Record 87 of Set 5 | Sandiacre
# Processing Record 5 of Set 8 | East San Gabriel
# Processing Record 88 of Set 5 | Medina de Pomar
# Processing Record 52 of Set 4 | Cividale del Friuli
# Processing Record 53 of Set 4 | Teresva
# Processing Record 6 of Set 8 | Yoshikawa
# Processing Record 112 of Set 6 | Bulwell
# Processing Record 113 of Set 6 | Tibau do Sul
# Processing Record 114 of Set 6 | Irapuato
# Processing Record 115 of Set 6 | Sagunto
# Processing Record 116 of Set 6 | Hanover
# Processing Record 7 of Set 8 | Wyoming
# Processing Record 117 of Set 6 | Slough
# Processing Record 118 of Set 6 | Oranjestad
# Processing Record 8 of Set 8 | Poulsbo
# Processing Record 9 of Set 8 | Pervouralsk
# Processing Record 119 of Set 6 | Yuzhnouralsk
# City not found: Mahmudabad Nemuneh
# Processing Record 54 of Set 4 | Dolni Lutyne
# Processing Record 121 of Set 6 | Nagtipunan
# Processing Record 10 of Set 8 | West Whittier-Los Nietos
# Processing Record 122 of Set 6 | Ancient Oaks
# Processing Record 123 of Set 6 | Cacimbas
# Processing Record 124 of Set 6 | San Carlos
# Processing Record 125 of Set 6 | Calatrava
# Processing Record 55 of Set 4 | Jubbah
# Processing Record 126 of Set 6 | Cotignola
# Processing Record 56 of Set 4 | Apolda
# Processing Record 127 of Set 6 | Dietlikon
# Processing Record 128 of Set 6 | Cuenca
# Processing Record 129 of Set 6 | Ardino
# Processing Record 57 of Set 4 | Chitcani
# Processing Record 11 of Set 8 | Scionzier
# Processing Record 58 of Set 4 | Krieglach
# Processing Record 59 of Set 4 | Schonefeld
# Number of cities retrieved: 563

# %%
print(f"Number of cities retrieved: {len(City)} ")
# Out:
# Number of cities retrieved: 563

# %%
pprint(city_response["id"])
pprint(city_response["name"])
pprint(city_response["clouds"]["all"])
pprint(city_response["sys"]["country"])
pprint(city_response["dt"])
pprint(city_response["main"]["humidity"])
pprint(city_response["coord"]["lat"])
pprint(city_response["coord"]["lon"])
pprint(city_response["main"]["temp_max"])
print(f"{city_response['wind']['speed']} mph")

print(f"{city_response['main']['temp']} farenheit")
print(f"{city_response['wind']['speed']} mph")
# Out:
# 2836761
# 'Schönefeld'
# 0
# 'DE'
# 1631426934
# 93
# 52.3833
# 13.5167
# 62.11
# 5.75 mph
# 59.88 farenheit
# 5.75 mph

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#output_data = zip()
#output_data =zip(City_ID,City,Cloudiness,Country,Date,Humidity,Lat,Lng,MaxTemp,WindSpeed)
#new_output_data =zip(City_ID,City,Cloudiness,Country,Date,Humidity,Lat,Lng,MaxTemp,WindSpeed)
#output_data_list = list(output_data)
#print(len(City_ID))

# %%
#output_data = zip()
output_data =zip(City_ID,City,Cloudiness,Country,Date,Humidity,Lat,Lng,MaxTemp,WindSpeed)
output_data_list = list(output_data)
output_file = os.path.join("..","Output_data","cities.csv")
# open the output file, create a header row, and then write the zipped object to the csv
with open(output_file, "w", newline='',encoding='utf-8') as datafile:
    writer = csv.writer(datafile)
    writer.writerow(["City_ID","City","Cloudiness","Country","Date","Humidity","Lat","Lng","Max Temp","Wind Speed"])
    writer.writerows(output_data_list)
output_data_df = pd.DataFrame(output_data_list, columns=("City_ID","City","Cloudiness","Country","Date","Humidity","Lat","Lng","Max Temp","Wind Speed"))
output_data_df
# Out:
#      City_ID            City  Cloudiness Country        Date  Humidity  \
# 0    6541260       Valenzano           0      IT  1631426312        83
# 1    3654055     Montecristi          90      EC  1631426314        83
# 2     461699          Sasovo          98      RU  1631426178        80
# 3    1938756  Pante Macassar          81      ID  1631426316        55
# 4    2948598      Birkenfeld          35      DE  1631426316        89
# ..       ...             ...         ...     ...         ...       ...
# 558   733638          Ardino          27      BG  1631426929        37
# 559   618067        Chiţcani         100      MD  1631426930        42
# 560  2975408       Scionzier           5      FR  1631426931        88
# 561  2773447       Krieglach          20      AT  1631426933        79
# 562  2836761      Schönefeld           0      DE  1631426934        93
#
#          Lat       Lng  Max Temp  Wind Speed
# 0    41.0453   16.8851     69.31        1.99
# 1    -1.0500  -80.6667     71.42       10.36
# 2    54.3537   41.9199     62.76        4.85
# 3    -9.2028  124.3684     88.02        4.52
# 4    48.8667    8.6333     56.91        2.13
# ..       ...       ...       ...         ...
# 558  41.5833   25.1333     52.23        3.80
# 559  46.7830   29.6168     68.52        6.38
# 560  46.0545    6.5576     62.22        2.66
# 561  47.5333   15.5500     57.56        1.59
# 562  52.3833   13.5167     62.11        5.75
#
# [563 rows x 10 columns]

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
cities_humidity_greater_than_100 = output_data_df.loc[(output_data_df["Humidity"] > 100)]
cities_humidity_greater_than_100
# Note none of the cities were > 100%.  Some were 100% maximum.
# Out:
# Empty DataFrame
# Columns: [City_ID, City, Cloudiness, Country, Date, Humidity, Lat, Lng, Max Temp, Wind Speed]
# Index: []

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %%
 output_data_df["Lat"].describe()
# Out:
# count    563.000000
# mean      32.029525
# std       22.944784
# min      -37.933300
# 25%       20.988500
# 50%       40.856600
# 75%       48.024350
# max       68.000000
# Name: Lat, dtype: float64

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Generate a scatter plot of Latitude vs Max Temperature (F)
y_axis = output_data_df["Max Temp"]
x_axis = output_data_df["Lat"]

plt.scatter(x_axis, y_axis, marker="o", facecolors="blue", edgecolors="black",
             alpha=0.75)
plt.title("City Latitude vs Max Temperature (F) (11/9/21)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid(True)
plt.tight_layout()

#plt.xlim(min(x_axis)-5,max(x_axis)+5)
#plt.ylim(min(y_axis)-5,max(y_axis)+5)
plt.savefig("../Output_data/Latitude_vs_temp.png")

# %%
print(x_axis)
# Out:
# 0      41.0453
# 1      -1.0500
# 2      54.3537
# 3      -9.2028
# 4      48.8667
#         ...
# 558    41.5833
# 559    46.7830
# 560    46.0545
# 561    47.5333
# 562    52.3833
# Name: Lat, Length: 563, dtype: float64

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Generate a scatter plot of Latitude vs Humidity %

plt.title("City Latitude vs Humidity (11/9/21)")
plt.xlabel("Latitude")
plt.ylabel("Humidity %")
y_axis = output_data_df["Humidity"]
x_axis = output_data_df["Lat"]
plt.scatter(x_axis, y_axis, marker="o", facecolors="blue", edgecolors="black",
           alpha=0.75)
plt.grid(True)
plt.tight_layout()
plt.savefig("../Output_data/Latitude_vs_Humidity.png")

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Generate a scatter plot of Latitude vs Cloudiness

plt.title("City Latitude vs Cloudiness (%) (11/9/21)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness %")
y_axis = output_data_df["Cloudiness"]
x_axis = output_data_df["Lat"]
plt.scatter(x_axis, y_axis, marker="o", facecolors="blue", edgecolors="black",
           alpha=0.75)
plt.grid(True)
plt.tight_layout()
plt.savefig("../Output_data/Latitude_vs_Cloudiness.png")

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Generate a scatter plot of Latitude vs Wind Speed

plt.title("City Latitude vs Wind Speed (mph) (11/9/21)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph))")
y_axis = output_data_df["Wind Speed"]
x_axis = output_data_df["Lat"]
plt.scatter(x_axis, y_axis, marker="o", facecolors="blue", edgecolors="black",
            alpha=0.75);
plt.grid(True)

plt.savefig("../Output_data/Latitude_vs_windspeed.png")

# %% [markdown]
# ## Linear Regression

# %%
# Create Southern and Northern hemisphere data sets
southern_output_data_df = output_data_df.loc[(output_data_df["Lat"] < 0)]
northern_output_data_df = output_data_df.loc[(output_data_df["Lat"] >= 0)]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Generate a scatter plot of Latitude vs Max Temperature

plt.title("Northern Hemishpere City Latitude vs Max Temp. (11/9/21)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
y_axis = northern_output_data_df["Max Temp"]
x_axis = northern_output_data_df["Lat"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.annotate(line_eq,(70,65),fontsize=15,color="red")
plt.grid(True)

plt.scatter(x_axis, y_axis, marker="o", facecolors="blue", edgecolors="black",
            alpha=0.75);
plt.plot(x_axis,regress_values,"r-");
print(f"The r-squared is: {rvalue**2}")
# Out:
# The r-squared is: 0.39157820244062874

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Generate a scatter plot of Latitude vs Max Temperature

plt.title("Southern Hemishpere City Latitude vs Max Temp. (11/9/21)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
y_axis = southern_output_data_df["Max Temp"]
x_axis = southern_output_data_df["Lat"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.annotate(line_eq,(0,65),fontsize=15,color="red")

plt.scatter(x_axis, y_axis, marker="o", facecolors="blue", edgecolors="black",
             alpha=0.75);
plt.plot(x_axis,regress_values,"r-");
plt.grid(True)
print(f"The r-squared is: {rvalue**2}")
# Out:
# The r-squared is: 0.20601848982984797

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Generate a scatter plot of Latitude vs Humidity %

plt.title("Northern Hemisphere City Latitude vs Humidity (11/9/21)")
plt.xlabel("Latitude")
plt.ylabel("Humidity %")
y_axis = northern_output_data_df["Humidity"]
x_axis = northern_output_data_df["Lat"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.annotate(line_eq,(65,50),fontsize=15,color="red")
plt.grid(True)
plt.scatter(x_axis, y_axis, marker="o", facecolors="blue", edgecolors="black",
            alpha=0.75);
plt.plot(x_axis,regress_values,"r-");
print(f"The r-squared is: {rvalue**2}")
# Out:
# The r-squared is: 0.004833607224960823

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Generate a scatter plot of Latitude vs Humidity %

plt.title("Southern Hemisphere City Latitude vs Humidity (11/9/21)")
plt.xlabel("Latitude")
plt.ylabel("Humidity %")
y_axis = southern_output_data_df["Humidity"]
x_axis = southern_output_data_df["Lat"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.annotate(line_eq,(65,50),fontsize=15,color="red")
plt.grid(True)
plt.scatter(x_axis, y_axis, marker="o", facecolors="blue", edgecolors="black",
            alpha=0.75);
plt.plot(x_axis,regress_values,"r-");
print(f"The r-squared is: {rvalue**2}")
# Out:
# The r-squared is: 0.03168876929951693

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Generate a scatter plot of Latitude vs Humidity

plt.title("Northern Hemisphere City Latitude vs Cloudiness (%) (11/9/21)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness %")
y_axis = northern_output_data_df["Cloudiness"]
x_axis = northern_output_data_df["Lat"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.annotate(line_eq,(65,50),fontsize=15,color="red")
plt.grid(True)
plt.scatter(x_axis, y_axis, marker="o", facecolors="blue", edgecolors="black",
            alpha=0.75);
plt.plot(x_axis,regress_values,"r-");
print(f"The r-squared is: {rvalue**2}")
# Out:
# The r-squared is: 0.01329183576855694

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Generate a scatter plot of Latitude vs Cloudiness

plt.title("Southern Hemisphere City Latitude vs Cloudiness (%) (11/9/21)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness %")
y_axis = southern_output_data_df["Cloudiness"]
x_axis = southern_output_data_df["Lat"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept

plt.annotate(line_eq,(65,50),fontsize=15,color="red")
plt.grid(True)
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_axis, y_axis, marker="o", facecolors="blue", edgecolors="black",
            alpha=0.75);
plt.plot(x_axis,regress_values,"r-");
print(f"The r-squared is: {rvalue**2}")
# Out:
# The r-squared is: 0.001961478760516364

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Generate a scatter plot of Latitude vs Wind Speed

plt.title("Northern Hemisphere City Latitude vs Wind Speed (mph) (11/9/21)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph))")
y_axis = northern_output_data_df["Wind Speed"]
x_axis = northern_output_data_df["Lat"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept

plt.annotate(line_eq,(65,15),fontsize=15,color="red")
plt.grid(True)
plt.scatter(x_axis, y_axis, marker="o", facecolors="blue", edgecolors="black",
            alpha=0.75);
plt.plot(x_axis,regress_values,"r-");
print(f"The r-squared is: {rvalue**2}")
# Out:
# The r-squared is: 0.0007240436135169356

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Generate a scatter plot of Latitude vs Wind Speed

plt.title("Southern Hemisphere City Latitude vs Wind Speed (mph) (11/9/21)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph))")
y_axis = southern_output_data_df["Wind Speed"]
x_axis = southern_output_data_df["Lat"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept

plt.annotate(line_eq,(65,15),fontsize=15,color="red")
plt.grid(True)
plt.scatter(x_axis, y_axis, marker="o", facecolors="blue", edgecolors="black",
            alpha=0.75);
plt.plot(x_axis,regress_values,"r-");
print(f"The r-squared is: {rvalue**2}")
# Out:
# The r-squared is: 0.03140446028817843
